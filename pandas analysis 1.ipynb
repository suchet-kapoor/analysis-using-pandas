# %%
import pandas as pd
import regex as re

# %%
s=pd.read_csv("pokemon.csv",usecols=["Grass"]).squeeze("columns")

# %%
s
# Out:
# 0         Type
# 1        Grass
# 2        Grass
# 3         Fire
# 4         Fire
#         ...
# 716       Dark
# 717     Dragon
# 718       Rock
# 719    Psychic
# 720       Fire
# Name: Grass, Length: 721, dtype: object

# %%
s=pd.read_csv("chicago.csv" )#worldstats #quarters #nba
s
# Out:
#                       Name            Position Title        Department  \
# 0          AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2           AARON,  KARINA            POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                       ...               ...
# 32058   ZYGOWICZ,  PETER J            POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E            POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E            POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST              DoIT
# 32062                  NaN                       NaN               NaN
#
#       Employee Annual Salary
# 0                  $90744.00
# 1                  $84450.00
# ...

# %%
s.columns #columns name to read headers
# Out:
# Index(['Name', 'Position Title', 'Department', 'Employee Annual Salary'], dtype='object')

# %%
s['Department'][0:30] #read each column
s['Department'][13] 
s[['Department','Name']]#read more than 1 column
# Out:
#              Department                 Name
# 0           WATER MGMNT      AARON,  ELVIA J
# 1                POLICE    AARON,  JEFFERY M
# 2                POLICE       AARON,  KARINA
# 3      GENERAL SERVICES  AARON,  KIMBERLEI R
# 4           WATER MGMNT  ABAD JR,  VICENTE M
# ...                 ...                  ...
# 32058            POLICE   ZYGOWICZ,  PETER J
# 32059            POLICE    ZYMANTAS,  MARK E
# 32060            POLICE  ZYRKOWSKI,  CARLO E
# 32061              DoIT  ZYSKOWSKI,  DARIUSZ
# 32062               NaN                  NaN
#
# [32063 rows x 2 columns]

# %%
#read each row
#s.head(6)
#s.iloc[2:7]
#s.iloc[5,2] to print [i,jth] element
#for i,j in s.iterrows():
  #  print(i,j['name'])
s.loc[s['Department']=='POLICE']
# Out:
#                       Name  Position Title Department Employee Annual Salary
# 1        AARON,  JEFFERY M  POLICE OFFICER     POLICE              $84450.00
# 2           AARON,  KARINA  POLICE OFFICER     POLICE              $84450.00
# 11        ABBATE,  TERRY M  POLICE OFFICER     POLICE              $90618.00
# 13       ABBOTT,  LYNISE M       CLERK III     POLICE              $46896.00
# 15         ABDALLAH,  ZAID  POLICE OFFICER     POLICE              $74028.00
# ...                    ...             ...        ...                    ...
# 32054       ZYCH,  MATEUSZ  POLICE OFFICER     POLICE              $46668.00
# 32055        ZYDEK,  BRYAN  POLICE OFFICER     POLICE              $81588.00
# 32058   ZYGOWICZ,  PETER J  POLICE OFFICER     POLICE              $87384.00
# 32059    ZYMANTAS,  MARK E  POLICE OFFICER     POLICE              $84450.00
# 32060  ZYRKOWSKI,  CARLO E  POLICE OFFICER     POLICE              $87384.00
#
# [12618 rows x 4 columns]

# %%
#s.describe()
s
# Out:
#                       Name            Position Title        Department  \
# 0          AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2           AARON,  KARINA            POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                       ...               ...
# 32058   ZYGOWICZ,  PETER J            POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E            POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E            POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST              DoIT
# 32062                  NaN                       NaN               NaN
#
#       Employee Annual Salary
# 0                  $90744.00
# 1                  $84450.00
# ...

# %%
s.sort_values(['Name','Department'],ascending=False)
# Out:
#                       Name                  Position Title        Department  \
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# ...                    ...                             ...               ...
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 0          AARON,  ELVIA J                WATER RATE TAKER       WATER MGMNT
# 32062                  NaN                             NaN               NaN
#
#       Employee Annual Salary
# ...

# %% [markdown]
# # MAKING CHANGES TO THE DATA

# %%
s.columns
# Out:
# Index(['Name', 'Position Title', 'Department', 'Employee Annual Salary'], dtype='object')

# %%
s['Total']=s['Employee Annual Salary']+s['Name'] #even after comment out our data is stll in the table.
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 s['Total']=s['Employee Annual Salary']+s['Name'] #even after comment out our data is stll in the table.
#       2 s
#
# File ~\filesofcode\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\filesofcode\Lib\site-packages\pandas\core\arraylike.py:102, in OpsMixin.__add__(self, other)
#     100 @unpack_zerodim_and_defer("__add__")
#     101 def __add__(self, other):
# --> 102     return self._arith_method(other, operator.add)
#
# File ~\filesofcode\Lib\site-packages\pandas\core\frame.py:7592, in DataFrame._arith_method(self, other, op)
#    7589 axis = 1  # only relevant for Series other case
# ...

# %%
#s.drop(columns=['Total'])
#s['total']=s.iloc[:,1:4].sum(axis=1) #another method to add 
#s[['total']]
#s.drop(32062,axis=0,inplace=True)
s
# Out:
#                       Name                  Position Title  \
# 0          AARON,  ELVIA J                WATER RATE TAKER
# 1        AARON,  JEFFERY M                  POLICE OFFICER
# 2           AARON,  KARINA                  POLICE OFFICER
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV
# ...                    ...                             ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST
#
#       Employee Annual Salary        Department Employee Annual Salary
# 0                  $90744.00       WATER MGMNT              $90744.00
# 1                  $84450.00            POLICE              $84450.00
# ...

# %%
col=list(s.columns.values)
s=s[col[0:2]+[col[-1]]+col[2:4]]
s.head(5)
# Out:
#                   Name            Position Title Employee Annual Salary  \
# 0      AARON,  ELVIA J          WATER RATE TAKER              $90744.00
# 1    AARON,  JEFFERY M            POLICE OFFICER              $84450.00
# 2       AARON,  KARINA            POLICE OFFICER              $84450.00
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER              $89880.00
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV             $106836.00
#
#          Department Employee Annual Salary
# 0       WATER MGMNT              $90744.00
# 1            POLICE              $84450.00
# 2            POLICE              $84450.00
# 3  GENERAL SERVICES              $89880.00
# 4       WATER MGMNT             $106836.00

# %% [markdown]
# saving it

# %%
#s.to_csv("modified.csv",index=False)
s.to_csv("modified.txt",index=False,sep='\t')
s
# Out:
#                       Name                  Position Title  \
# 0          AARON,  ELVIA J                WATER RATE TAKER
# 1        AARON,  JEFFERY M                  POLICE OFFICER
# 2           AARON,  KARINA                  POLICE OFFICER
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV
# ...                    ...                             ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST
#
#       Employee Annual Salary        Department Employee Annual Salary
# 0                  $90744.00       WATER MGMNT              $90744.00
# 1                  $84450.00            POLICE              $84450.00
# ...

# %% [markdown]
# # _filtering data

# %%
 import re
#a=s.loc[(s['Name']=='ABAMH') |(s['Department']=='GENERAL SERVICES') & (s['Employee Annual Salary']>'$99580')]
#a=a.reset_index()
#a=a.reset_index(drop=True)
#a=a.reset_index(drop=True,inplace=True)
 s.loc[s['Name'].str.contains('ABB',regex=True)]
# Out:
#                          Name                   Position Title  \
# 8        ABBASI,  CHRISTOPHER       STAFF ASST TO THE ALDERMAN
# 9       ABBATACOLA,  ROBERT J              ELECTRICAL MECHANIC
# 10      ABBATEMARCO,  JAMES J                FIRE ENGINEER-EMT
# 11           ABBATE,  TERRY M                   POLICE OFFICER
# 12           ABBOTT,  BETTY L               FOSTER GRANDPARENT
# 13          ABBOTT,  LYNISE M                        CLERK III
# 14     ABBRUZZESE,  WILLIAM J           INVESTIGATOR - IPRA II
# 6158          DABBS,  CARNELL               MOTOR TRUCK DRIVER
# 6159            DABBS,  MAE E  COMMUNICATIONS OPERATOR I - 311
# 11224             HALL,  ABBY                ASST TO THE MAYOR
# 15551         LABBE,  JAMES C                         SERGEANT
# 18525     MC NABB,  STEPHEN P                FIRE ENGINEER-EMT
# 25152       SABBIA,  DANIEL S                          LABORER
# 25153      SABBIA JR,  JOHN P          POOL MOTOR TRUCK DRIVER
# ...

# %%
import re
s.loc[s['Name'].str.contains('ABBOTT|ZYcH',regex=True,flags=re.I)]
# Out:
#                     Name      Position Title Employee Annual Salary  \
# 12      ABBOTT,  BETTY L  FOSTER GRANDPARENT               $2756.00
# 13     ABBOTT,  LYNISE M           CLERK III              $46896.00
# 32054     ZYCH,  MATEUSZ      POLICE OFFICER              $46668.00
#
#              Department Employee Annual Salary
# 12     FAMILY & SUPPORT               $2756.00
# 13               POLICE              $46896.00
# 32054            POLICE              $46668.00

# %%
a=s.loc[s['Name'].str.contains('AB[a-z]*',regex=True,flags=re.I)]#all names starting with ABB then others
a=s.loc[s['Name'].str.contains('^AB[a-z]*',regex=True,flags=re.I)]#all names starting with ABB only these ones
a
# Out:
#                         Name  \
# 4        ABAD JR,  VICENTE M
# 5            ABARCA,  ANABEL
# 6          ABARCA,  EMMANUEL
# 7          ABASCAL,  REECE E
# 8       ABBASI,  CHRISTOPHER
# 9      ABBATACOLA,  ROBERT J
# 10     ABBATEMARCO,  JAMES J
# 11          ABBATE,  TERRY M
# 12          ABBOTT,  BETTY L
# 13         ABBOTT,  LYNISE M
# 14    ABBRUZZESE,  WILLIAM J
# 15           ABDALLAH,  ZAID
# 16     ABDELHADI,  ABDALMAHD
# 17       ABDELLATIF,  AREF R
# 18        ABDELMAJEID,  AZIZ
# 19       ABDOLLAHZADEH,  ALI
# 20  ABDUL-KARIM,  MUHAMMAD A
# 21       ABDULLAH,  DANIEL N
# 22          ABDULLAH,  KEVIN
# 23      ABDULLAH,  LAKENYA N
# 24       ABDULLAH,  RASHAD J
# 25      ABDULSATTAR,  MUDHAR
# 26      ABDUL-SHAKUR,  TAHIR
# 27    ABDULWAHAB,  ABUUBAIDA
# 28         ABEJERO,  JASON V
# 29   ABERCROMBIE IV,  EARL S
# 30     ABERCROMBIE,  TIMOTHY
# 31        ABIOYE,  ADEWOLE A
# 32           ABNEY,  PATRICK
# 33    ABOUELKHEIR,  HASSAN A
# 34        ABRAHAM,  GIRLEY T
# ...

# %% [markdown]
# conditional changes

# %%
a=s.loc[s['Department']=='POLICE','Department']='coronagocorona'
s
# Out:
# C:\Users\suche\AppData\Local\Temp\ipykernel_5464\819577396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a=s.loc[s['Department']=='POLICE','Department']='coronagocorona'
#                       Name                  Position Title  \
# 0          AARON,  ELVIA J                WATER RATE TAKER
# 1        AARON,  JEFFERY M                  POLICE OFFICER
# 2           AARON,  KARINA                  POLICE OFFICER
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV
# ...                    ...                             ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER
# ...

# %%
#s.loc[s['Employee Annual Salary']>'$87384',['Department']]='$4454'
s
# Out:
#                       Name                  Position Title  \
# 0          AARON,  ELVIA J                WATER RATE TAKER
# 1        AARON,  JEFFERY M                  POLICE OFFICER
# 2           AARON,  KARINA                  POLICE OFFICER
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV
# ...                    ...                             ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST
#
#       Employee Annual Salary        Department Employee Annual Salary
# 0                  $90744.00       WATER MGMNT              $90744.00
# 1                  $84450.00    coronagocorona              $84450.00
# ...

# %%
s=pd.read_csv('modified.csv')
s.groupby(['Position Title']).mean()
# Out:
# C:\Users\suche\AppData\Local\Temp\ipykernel_5464\3027015917.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   s.groupby(['Position Title']).mean()
#                                 Unnamed: 0
# Position Title
# 1ST DEPUTY INSPECTOR GENERAL   7602.000000
# A/MGR COM SVC-ELECTIONS       10858.000000
# A/MGR OF MIS-ELECTIONS        28940.000000
# A/MGR WAREHOUSE-ELECTIONS     12974.000000
# A/SUPRV REDISTRICTING         23895.500000
# ...                                    ...
# WINDOW WASHER                 20438.500000
# YOUTH SERVICES COORD          17555.571429
# ZONING ADMINISTRATOR          25947.000000
# ZONING INVESTIGATOR           23282.000000
# ZONING PLAN EXAMINER           7161.000000
#
# [1093 rows x 1 columns]

# %% [markdown]
# aggregate statistics (groupby)

# %%
s=pd.read_csv('modified.csv')

# %%
s['count']=1
s.groupby(['Position Title','Name']).count()['count']
# Out:
# Position Title                Name
# 1ST DEPUTY INSPECTOR GENERAL  DUNN,  BRIAN J       1
# A/MGR COM SVC-ELECTIONS       GRIMM,  LAURA A      1
# A/MGR OF MIS-ELECTIONS        TRAN,  TIEN K        1
# A/MGR WAREHOUSE-ELECTIONS     HURDE,  DERRICK L    1
# A/SUPRV REDISTRICTING         MILLER,  THOMAS F    1
#                                                   ..
# ZONING PLAN EXAMINER          DIAZ,  EDGAR         1
#                               DUPLAGA,  ALICIA     1
#                               GAETA,  JOSE O       1
#                               HILL,  JANICE D      1
#                               HUSSAIN,  SYED S     1
# Name: count, Length: 32017, dtype: int64

# %% [markdown]
# working withlarge amount of data

# %%
a=pd.DataFrame(columns=s.columns)
for s in  pd.read_csv('modified.csv',chunksize=5):
 #   print(s)
    
 results=s.groupby(['Name']).count()
a=pd.concat([a,results])
a
# Out:
#                     Unnamed: 0 Name Position Title Employee Annual Salary  \
# ZYRKOWSKI,  CARLO E          1  NaN              1                      1
# ZYSKOWSKI,  DARIUSZ          1  NaN              1                      1
#
#                     Department Employee Annual Salary.1
# ZYRKOWSKI,  CARLO E          1                        1
# ZYSKOWSKI,  DARIUSZ          1                        1

# %%
 a
# Out:
#                     Unnamed: 0 Name Position Title Employee Annual Salary  \
# ZYRKOWSKI,  CARLO E          1  NaN              1                      1
# ZYSKOWSKI,  DARIUSZ          1  NaN              1                      1
#
#                     Department Employee Annual Salary.1
# ZYRKOWSKI,  CARLO E          1                        1
# ZYSKOWSKI,  DARIUSZ          1                        1
